# %%
import pandas as pd
import seaborn as sns

df1 = pd.read_csv("/home/max/Desktop/Nadia-2021/30 de Septiembre/datosDeVacunasDadas.csv",sep=",",engine="python")

grafico = sns.pairplot(df1,hue="grupo_etario",palette="Spectral")
