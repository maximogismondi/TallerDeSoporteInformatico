# %%
import pandas as pd
import seaborn as sns

df1 = pd.read_csv("Air_Quality.csv",sep=",",engine="python")
grafico = sns.pairplot(df1, hue="state", vars=["pollutant_min","pollutant_max","pollutant_avg"])
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
